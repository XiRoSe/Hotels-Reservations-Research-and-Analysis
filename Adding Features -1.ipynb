# %%
import pandas as pd
fd = pd.read_csv("hotels_data.csv",parse_dates=[1,2])
fd.head()
# Out:
#    Snapshot ID Snapshot Date Checkin Date  Days  Original Price  \
# 0            1    2015-07-17   2015-08-12     5            1178
# 1            1    2015-07-17   2015-08-19     5            1113
# 2            1    2015-07-17   2015-08-13     5            4370
# 3            1    2015-07-17   2015-07-26     5            1739
# 4            1    2015-07-17   2015-08-12     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars
# 0  Best Western Plus Seaport Inn Downtown            3
# 1  Best Western Plus Seaport Inn Downtown            3
# 2                  The Peninsula New York            5
# ...

# %%
fd['Day Diff']=(fd['Checkin Date']-fd['Snapshot Date']).dt.days
fd.head()
# Out:
#    Snapshot ID Snapshot Date Checkin Date  Days  Original Price  \
# 0            1    2015-07-17   2015-08-12     5            1178
# 1            1    2015-07-17   2015-08-19     5            1113
# 2            1    2015-07-17   2015-08-13     5            4370
# 3            1    2015-07-17   2015-07-26     5            1739
# 4            1    2015-07-17   2015-08-12     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars  Day Diff
# 0  Best Western Plus Seaport Inn Downtown            3        26
# 1  Best Western Plus Seaport Inn Downtown            3        33
# 2                  The Peninsula New York            5        27
# ...

# %%
fd['WeekDay'] = fd['Checkin Date'].dt.weekday_name
fd.head()
# Out:
#    Snapshot ID Snapshot Date Checkin Date  Days  Original Price  \
# 0            1    2015-07-17   2015-08-12     5            1178
# 1            1    2015-07-17   2015-08-19     5            1113
# 2            1    2015-07-17   2015-08-13     5            4370
# 3            1    2015-07-17   2015-07-26     5            1739
# 4            1    2015-07-17   2015-08-12     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars  Day Diff    WeekDay
# 0  Best Western Plus Seaport Inn Downtown            3        26  Wednesday
# 1  Best Western Plus Seaport Inn Downtown            3        33  Wednesday
# ...

# %%
fd['Discount Diff']=(fd['Original Price']-fd['Discount Price'])
fd.head()
# Out:
#    Snapshot ID Snapshot Date Checkin Date  Days  Original Price  \
# 0            1    2015-07-17   2015-08-12     5            1178
# 1            1    2015-07-17   2015-08-19     5            1113
# 2            1    2015-07-17   2015-08-13     5            4370
# 3            1    2015-07-17   2015-07-26     5            1739
# 4            1    2015-07-17   2015-08-12     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars  Day Diff    WeekDay  \
# 0  Best Western Plus Seaport Inn Downtown            3        26  Wednesday
# 1  Best Western Plus Seaport Inn Downtown            3        33  Wednesday
# ...

# %%
fd['Discount Perc']=((fd['Discount Diff']*100)/fd['Original Price'])
fd['Discount Perc'].format = '{:,.2f}'.format
fd.head()
# Out:
#    Snapshot ID Snapshot Date Checkin Date  Days  Original Price  \
# 0            1    2015-07-17   2015-08-12     5            1178
# 1            1    2015-07-17   2015-08-19     5            1113
# 2            1    2015-07-17   2015-08-13     5            4370
# 3            1    2015-07-17   2015-07-26     5            1739
# 4            1    2015-07-17   2015-08-12     5            1739
#
#    Discount Price  Discount Code  Available Rooms  \
# 0            1040              1                6
# 1             982              1                8
# 2            4240              1                3
# 3            1667              1               18
# 4            1672              1                3
#
#                                Hotel Name  Hotel Stars  Day Diff    WeekDay  \
# 0  Best Western Plus Seaport Inn Downtown            3        26  Wednesday
# 1  Best Western Plus Seaport Inn Downtown            3        33  Wednesday
# ...

# %%
fd.to_csv('Hotels_data_Changed.csv',encoding='UTF-8')
